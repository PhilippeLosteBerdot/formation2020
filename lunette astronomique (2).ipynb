# %% [markdown]
# 1. aaa
# 2. bbb
# 3. ccc

# %% [markdown]
# ![texte alternatif](https://www.natureetdecouvertes.com/fstrz/r/s/cache.natureetdecouvertes.com/Medias/Images/Articles/53151570/53151570-lunette-mizar-70-900_P1.jpg?frz-v=279)
